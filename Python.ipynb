# %% [markdown]
# <a href="https://colab.research.google.com/github/PavanChikkodikar/Python/blob/main/Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Keywords/Reserve words in programming language
#
# 1. C - 32
# 2. C++ - 95
# 3. Java - 68
# 4. Python - 35
#
#
#
# ####################################################
#
# *   Most of the datatypes in python are immutable
# *   Everything in python is a **Object**
# *   Literals are used to represent specific values in a human-readable form directly in your code, If we are directly assigning a value to a variable (for ex : price = 250, width = 800, height = 600) then it is nothing but a literal
# *

# %%
a = 12345678912321381378
print(a)
print(type(a))
print(a.__sizeof__() ," bytes")
# Out:
# 12345678912321381378
# <class 'int'>
# 36  bytes

# %%
# !pip install opencv-python
import cv2
from google.colab.patches import cv2_imshow

image = cv2.imread('/content/Data_Types.png')

if image is not None:
    cv2_imshow(image)
else:
    print("Image not found or couldn't be loaded.")

    # Data types in python 👇
# Out:
# <PIL.Image.Image image mode=RGB size=2880x1800>

# %%
# complex no datatype
x = complex(10,20)
print(x)
y = 11+22j
print(y)
print(x.real)
print(x.imag)
# Out:
# (10+20j)
# (11+22j)
# 10.0
# 20.0

# %%
# Conversion of no

a = 10
print(bin(a))
print(hex(a))
print(oct(a))
# Out:
# 0b1010
# 0xa
# 0o12

# %%
# Type Conversion
# 1. Implicit - conversion is done by python
# 2. Explicit - programmer should do this, not done by python

import cv2
from google.colab.patches import cv2_imshow
image = cv2.imread('/content/Screenshot 2023-10-26 at 9.37.43 AM.png')

if image is not None:
    cv2_imshow(image)
else:
    print("Image not found or couldn't be loaded.")
# Out:
# <PIL.Image.Image image mode=RGB size=2880x1800>
